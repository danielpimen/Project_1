# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from matplotlib.ticker import FuncFormatter

wdi = pd.read_csv("WDIData.csv")
print(wdi.shape)
# Out:
# (422136, 64)

# %%
data = pd.read_csv('WDIData.csv')
data.shape
# Out:
# (422136, 64)

# %%
data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# ...

# %%
refugee_count_table = data[data['Indicator Name'].str.contains('Refugee population by country or territory of asylum')]
#refugee_count.head()
refugee_indicator = "Refugee population by country or territory of asylum"
refugee_country_usa = "USA"
refugee_count = data.loc[(data["Country Code"] == "USA") & (data["Indicator Name"] == "Refugee population by country or territory of asylum") ]
refugee_count_df = pd.DataFrame(refugee_count)
refugee_count_df.drop(refugee_count_df.iloc[: , 0:34], axis = 1, inplace =True)
refugee_count_df
# Out:
#             1990      1991      1992      1993      1994      1995      1996  \
# 405869  464887.0  513882.0  579952.0  623069.0  631051.0  623294.0  607024.0
#
#             1997      1998      1999  ...      2010      2011      2012  \
# 405869  563837.0  533969.0  521143.0  ...  264574.0  264763.0  262023.0
#
#             2013      2014      2015      2016      2017      2018  \
# 405869  263662.0  267222.0  273202.0  272959.0  287065.0  313241.0
#
#         Unnamed: 63
# 405869          NaN
#
# [1 rows x 30 columns]

# %%
refugee_count_df
test=refugee_count_df.transpose()
test
# Out:
#                405869
# 1990         464887.0
# 1991         513882.0
# 1992         579952.0
# 1993         623069.0
# 1994         631051.0
# 1995         623294.0
# 1996         607024.0
# 1997         563837.0
# 1998         533969.0
# 1999         521143.0
# 2000         508222.0
# 2001         515853.0
# 2002         485171.0
# 2003         452548.0
# 2004         420854.0
# 2005         379340.0
# 2006         843498.0
# 2007         281219.0
# 2008         279548.0
# 2009         275461.0
# 2010         264574.0
# 2011         264763.0
# 2012         262023.0
# 2013         263662.0
# 2014         267222.0
# 2015         273202.0
# 2016         272959.0
# 2017         287065.0
# 2018         313241.0
# Unnamed: 63       NaN

# %%
y_axis = np.arange(200000, 900000, 100000)
#plt.plot(refugee_count_df)
plt.plot(y_axis , )
plt.ylabel = "Volume of Refugees to USA"
plt.show()

# %%
#Arms Exports from Data
arms_stage = data[data['Indicator Name'].str.contains('Arms exports \(SIPRI')]
arms_stage.shape
# Out:
# (264, 64)

# %%
arms_count_table = data[data['Indicator Name'].str.contains('Arms exports (SIPRI trend indicator values)')]
#refugee_count.head()
arms_indicator = "Arms exports (SIPRI trend indicator values)"
arms_country_usa = "USA"
arms_count = data.loc[(data["Country Code"] == "USA") & (data["Indicator Name"] == "Arms exports (SIPRI trend indicator values)") ]
arms_count_df = pd.DataFrame(arms_count)
arms_count_df.drop(arms_count_df.iloc[: , 0:34], axis = 1, inplace =True)
test2=arms_count_df.transpose()
plt.plot(test2)
plt.ylabel = "Arms Exports from USA"
plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   """Entry point for launching an IPython kernel.

# %%
# years = arms_stage['Year'].values
# years
test=arms_stage[['Country Name','2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']]
test=test.melt(id_vars=['Country Name'],var_name='Year',value_name='Arms Export per Capita')
# test=test.transpose()
USA=test.loc[test['Country Name']=='United States']
globe=test['Country Name'].isin(['United States'])
globaldata=test[~globe]
globaldata=globaldata.groupby(['Year']).sum()
USA=USA.groupby(['Year']).sum()

# %%
Year=['2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018']
value1=USA['Arms Export per Capita'].tolist()
# value
USAplot=plt.bar(Year,value1,color='blue')

# %%
value2=globaldata['Arms Export per Capita'].tolist()
Globalplot=plt.bar(Year,value2,color='red')

# %%
fig=plt.figure()
ax=fig.add_subplot(111)

plt.bar(Year,value1,color='blue',alpha=0.3)
plt.bar(Year,value2,color='red',alpha=0.2)
ax.legend((USAplot,Globalplot),('USA','Global'))
plt.show()

# %%
import matplotlib.pyplot as plt

labels = '2008','2009','2010','2011','2012','2013','2014','2015','2016','2017','2018'
sizes = [75, 56, 49, 56, 68, 67, 75, 78, 68, 69, 80]


fig1, ax1 = plt.subplots()
ax1.pie(sizes , labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %%
# select Arms export for the World
hist_indicator = 'Arms exports \(SIPRI'
hist_year = 2014
hist_country = 'USA'

mask1 = data['Indicator Name'].str.contains(hist_indicator) 
#mask2 = data['Year,value1'].isin([hist_year])

mask3 = data['Country Code'].str.contains(hist_country)


# stage is just those indicators matching the 1980 for year and Arms export over time.
usa_stage = data[mask1 & mask3]
usa_67 = data[mask1 & mask2 & mask3]

# %%
usa_stage.head(11)
# Out:
#          Country Name Country Code  \
# 404644  United States          USA
#
#                                      Indicator Name  Indicator Code  \
# 404644  Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
#
#                 1960          1961          1962          1963          1964  \
# 404644  6.055000e+09  6.330000e+09  5.938000e+09  8.944000e+09  1.223500e+10
#
#                 1965  ...          2010          2011          2012  \
# 404644  1.115500e+10  ...  8.074000e+09  9.022000e+09  9.086000e+09
#
#                 2013          2014          2015          2016          2017  \
# 404644  7.571000e+09  9.601000e+09  9.931000e+09  9.955000e+09  1.248500e+10
#
#                 2018  Unnamed: 63
# 404644  1.050800e+10          NaN
#
# [1 rows x 64 columns]

# %%
type(usa_stage)
# Out:
# pandas.core.frame.DataFrame

# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('WDIData.csv')
data.shape
# Out:
# (422136, 64)

# %%
data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# ...

# %%
countries = data['Country Name'].unique().tolist()
len(countries)
# Out:
# 264

# %%
#How many unique indicators are there ? (should be the same #)
indicators = data['Indicator Name'].unique().tolist()
len(indicators)
# Out:
# 1599

# %%
print(all)
# Out:
# <built-in function all>

# %%
# select CO2 emissions for the United States
hist_indicator = 'CO2 emissions \(metric'
hist_country = 'USA'

mask1 = data['Indicator Name'].str.contains(hist_indicator) 
mask2 = data['Country Code'].str.contains(hist_country)


stage = data[mask1 & mask2]

# %%
stage.head()
# Out:
#          Country Name Country Code                          Indicator Name  \
# 404754  United States          USA  CO2 emissions (metric tons per capita)
#
#         Indicator Code       1960       1961       1962       1963       1964  \
# 404754  EN.ATM.CO2E.PC  15.999779  15.681256  16.013937  16.482762  16.968119
#
#              1965  ...       2010       2011       2012       2013       2014  \
# 404754  17.451725  ...  17.442862  16.976957  16.310471  16.323477  16.502837
#
#         2015  2016  2017  2018  Unnamed: 63
# 404754   NaN   NaN   NaN   NaN          NaN
#
# [1 rows x 64 columns]

# %%
# the histogram of the data
hist_data = stage['Indicator Name'].values
plt.hist(hist_data, 10, normed=False, facecolor='green')

plt.xlabel(stage['Indicator Name'].iloc[0])
plt.ylabel('# of Years')
plt.title('Histogram Example')

plt.grid(True)

plt.show()
# Out:
# //anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-291-86bf56a5b9c3> in <module>
#       4
#       5 plt.xlabel(stage['Indicator Name'].iloc[0])
# ----> 6 plt.ylabel('# of Years')
#       7 plt.title('Histogram Example')
#       8
#
# TypeError: 'str' object is not callable

# %%
print("GDP Min Year = ", gdp_stage['Year'].min(), "max: ", gdp_stage['Year'].max())
print("CO2 Min Year = ", stage['Year'].min(), "max: ", stage['Year'].max())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# //anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Year'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-293-533a5c88b8c7> in <module>
# ...

# %%
gdp_stage_trunc = gdp_stage[gdp_stage ['2012']
print(len(gdp_stage_trunc))
print(len(stage))
# Out:
#   File "<ipython-input-300-780d994edf84>", line 2
#     print(len(gdp_stage)
#         ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
import matplotlib.pyplot as plt



fig, axis = plt.subplots()
# Grid lines, Xticks, Xlabel, Ylabel

axis.yaxis.grid(True)
axis.set_title('CO2 Emissions vs. GDP \(per capita\)',fontsize=10)
axis.set_xlabel(gdp_stage_trunc['IndicatorName'].iloc[0],fontsize=10)
axis.set_ylabel(stage['IndicatorName'].iloc[0],fontsize=10)

X = gdp_stage_trunc['Value']
Y = stage['Value']

axis.scatter(X, Y)
plt.show()
# Out:
#   File "<ipython-input-297-de3134ecc40d>", line 5
#     print(len(gdp_stage_trunc))
#         ^
# SyntaxError: invalid syntax
