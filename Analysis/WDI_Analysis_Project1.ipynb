# %%
#Import Dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from matplotlib.ticker import FuncFormatter

#Read CSV and Read Shape
wdi = pd.read_csv("WDIData.csv")
print(wdi.shape)
# Out:
# (422136, 64)

# %%
#Get Data
data = pd.read_csv('WDIData.csv')
data.shape
# Out:
# (422136, 64)

# %%
#See Shape
data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# ...

# %% [markdown]
# # How Many Refugees has the United States been accepting according to World Bank?

# %%
#Grab the column listing number of Refugees accepted by USA
rg_df = data.loc[(data["Country Code"] == "USA") & (data["Indicator Name"] == "Refugee population by country or territory of asylum") ]
rg_df_v2 = pd.DataFrame(rg_df)
rg_df_v2.drop(rg_df_v2.iloc[: , 0:34], axis = 1, inplace =True)
rg_df_v2.rename(index= { 405869 :'Refugees Accepted (USA)' }, inplace = True)
rg_df_v3 = rg_df_v2.transpose()
rg_df_v3.drop(rg_df_v3.tail(1).index,inplace=True)
rg_df_v3
# Out:
#       Refugees Accepted (USA)
# 1990                 464887.0
# 1991                 513882.0
# 1992                 579952.0
# 1993                 623069.0
# 1994                 631051.0
# 1995                 623294.0
# 1996                 607024.0
# 1997                 563837.0
# 1998                 533969.0
# 1999                 521143.0
# 2000                 508222.0
# 2001                 515853.0
# 2002                 485171.0
# 2003                 452548.0
# 2004                 420854.0
# 2005                 379340.0
# 2006                 843498.0
# 2007                 281219.0
# 2008                 279548.0
# 2009                 275461.0
# 2010                 264574.0
# 2011                 264763.0
# 2012                 262023.0
# 2013                 263662.0
# 2014                 267222.0
# 2015                 273202.0
# 2016                 272959.0
# 2017                 287065.0
# 2018                 313241.0

# %%
#Set x and y axis
x_axis_data = np.arange(1990, 2018, 1)
#rg_df_v3["Year"] = rg_df_v3.index
#rg_df_v3["Year"] = np.nan
y_axis_data = [464887, 513882, 579952, 623069, 631051, 623294, 607024, 563837, 533969, 521143, 508222, 515853, 485171, 452548, 420854,379340, 843498, 281219,278548,275461,264763,262023,263662,267222,263202,272959,287065,313241]
plt.plot(x_axis_data, y_axis_data )
plt.title = "# of Refugees to USA"
plt.xlabel = "Arms Exports from USA"
plt.ylabel = "Arms Exports from USA"
plt.legend(["Refugees Admitted to the US"])
plt.show()

# %%
arms_data_us = arms_count = data.loc[(data["Country Code"] == "USA") & (data["Indicator Name"] == "Arms exports (SIPRI trend indicator values)") ]

arms_df = pd.DataFrame(arms_data_us)
arms_df_v2 = arms_df.transpose()
arms_df_v2.drop(arms_df_v2.tail(1).index,inplace=True)

arms_df_v2.reset_index(level=0, inplace=True)
arms_df_v2.columns = ['Year', 'Arms Exports (Bilions $USD)']
#arms_df_v2.drop(arms_df_v2.index[[0,1,2,3]])
#arms_df_v2

# %%
arms_df_v3 = arms_df_v2.drop(arms_df_v2.index[[0,1,2,3]])
arms_df_v3
# Out:
#     Year Arms Exports (Bilions $USD)
# 4   1960                   6.055e+09
# 5   1961                    6.33e+09
# 6   1962                   5.938e+09
# 7   1963                   8.944e+09
# 8   1964                  1.2235e+10
# 9   1965                  1.1155e+10
# 10  1966                   8.404e+09
# 11  1967                   7.256e+09
# 12  1968                   8.447e+09
# 13  1969                  1.1773e+10
# 14  1970                   9.017e+09
# 15  1971                   1.172e+10
# 16  1972                  1.0787e+10
# 17  1973                  1.2033e+10
# 18  1974                  1.2752e+10
# 19  1975                  1.5706e+10
# 20  1976                  1.5662e+10
# 21  1977                  1.4389e+10
# 22  1978                  1.4083e+10
# 23  1979                   9.725e+09
# 24  1980                   1.073e+10
# 25  1981                  1.3611e+10
# 26  1982                  1.4015e+10
# 27  1983                  1.3939e+10
# ...

# %%
#plt.plot(arms_df_v3)
#plt.ylabel = "Arms Exports from USA"
#plt.show()

# %%
arms_count = data.loc[(data["Country Code"] == "USA") & (data["Indicator Name"] == "Arms exports (SIPRI trend indicator values)") ]
arms_count_df = pd.DataFrame(arms_count)
arms_count_df.drop(arms_count_df.iloc[: , 0:34], axis = 1, inplace =True)
test2=arms_count_df.transpose()
plt.plot(test2)
plt.ylabel = "Arms Exports from USA"
plt.show()

# %%
data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# ...

# %%
arms_df_pie = data.loc[ (data["Indicator Name"] == "Arms exports (SIPRI trend indicator values)") ]
#arms_df_pie= data.loc[(data["2018"]) & (data["Indicator Name"] == "Arms exports (SIPRI trend indicator values)") ]
arms_df_pie = pd.DataFrame(arms_list)
arms_df_pie.transpose()
# Out:
#                                                         0    \
# index                                                    97
# Country Name                                     Arab World
# Country Code                                            ARB
# Indicator Name  Arms exports (SIPRI trend indicator values)
# Indicator Code                               MS.MIL.XPRT.KD
# 1960                                                  3e+06
# 1961                                                    NaN
# 1962                                                  9e+06
# 1963                                                  8e+06
# 1964                                                  2e+06
# 1965                                                    NaN
# 1966                                                1.3e+07
# 1967                                                1.2e+07
# 1968                                                3.5e+07
# 1969                                                2.1e+07
# ...

# %%
arms_df_pie.drop(arms_df_pie.tail(1).index,inplace=True)
arms_df_pie
# Out:
#       index                                       Country Name Country Code  \
# 0        97                                         Arab World          ARB
# 1      1696                             Caribbean small states          CSS
# 2      3295                     Central Europe and the Baltics          CEB
# 3      4894                         Early-demographic dividend          EAR
# 4      6493                                East Asia & Pacific          EAS
# 5      8092        East Asia & Pacific (excluding high income)          EAP
# 6      9691         East Asia & Pacific (IDA & IBRD countries)          TEA
# 7     11290                                          Euro area          EMU
# 8     12889                              Europe & Central Asia          ECS
# 9     14488      Europe & Central Asia (excluding high income)          ECA
# 10    16087       Europe & Central Asia (IDA & IBRD countries)          TEC
# ...

# %%
arms_df_pie.reset_index(level=0, inplace=True)
arms_df_pie
# Out:
#      level_0   index                                       Country Name  \
# 0          0      97                                         Arab World
# 1          1    1696                             Caribbean small states
# 2          2    3295                     Central Europe and the Baltics
# 3          3    4894                         Early-demographic dividend
# 4          4    6493                                East Asia & Pacific
# 5          5    8092        East Asia & Pacific (excluding high income)
# 6          6    9691         East Asia & Pacific (IDA & IBRD countries)
# 7          7   11290                                          Euro area
# 8          8   12889                              Europe & Central Asia
# 9          9   14488      Europe & Central Asia (excluding high income)
# 10        10   16087       Europe & Central Asia (IDA & IBRD countries)
# 11        11   17686                                     European Union
# ...

# %%
#2018 Summary
#arms_df_pie.drop('1960', axis=1)
#arms_df_pie

country_list = ['EU', 'China', 'India', 'Russia', 'United States']
sales_2018 =[6311, 1040, 46, 6409, 10508]
x_axis = np.arange(len(sales_2018))
plt.legend(["Arms Exports in Millions"])
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["EU", "China", "India", "Russia", "United States"])
plt.bar(x_axis, sales_2018, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 5 artists>

# %%
country_list_2 = ['EU', 'China', 'India', 'Russia', 'United States']
imports_2018 =[1982, 1566, 1539, 26, 613]
x_axis = np.arange(len(imports_2018))
plt.legend(["Arms Imports in Millions"])
tick_locations = [value for value in x_axis]
plt.xticks(tick_locations, ["EU", "China", "India", "Russia", "United States"])
plt.bar(x_axis, imports_2018, color='r', alpha=0.5, align="center")
# Out:
# <BarContainer object of 5 artists>
