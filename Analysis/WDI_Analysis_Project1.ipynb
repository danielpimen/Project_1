# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import random
from matplotlib.ticker import FuncFormatter

wdi = pd.read_csv("WDIData.csv")
print(wdi.shape)
# Out:
# (422136, 64)

# %%
data = pd.read_csv('WDIData.csv')
data.shape
# Out:
# (422136, 64)

# %%
data.head(10)
# Out:
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
# 5   Arab World          ARB
# 6   Arab World          ARB
# 7   Arab World          ARB
# 8   Arab World          ARB
# 9   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
# 5  Access to electricity, urban (% of urban popul...  EG.ELC.ACCS.UR.ZS   NaN
# 6  Account ownership at a financial institution o...     FX.OWN.TOTL.ZS   NaN
# ...

# %%
arms_stage = data[data['Indicator Name'].str.contains('Arms exports \(SIPRI')]
arms_stage.head()
# Out:
#                         Country Name Country Code  \
# 97                        Arab World          ARB
# 1696          Caribbean small states          CSS
# 3295  Central Europe and the Baltics          CEB
# 4894      Early-demographic dividend          EAR
# 6493             East Asia & Pacific          EAS
#
#                                    Indicator Name  Indicator Code  \
# 97    Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
# 1696  Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
# 3295  Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
# 4894  Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
# 6493  Arms exports (SIPRI trend indicator values)  MS.MIL.XPRT.KD
#
#              1960        1961         1962         1963         1964  \
# 97      3000000.0         NaN    9000000.0    8000000.0    2000000.0
# 1696          NaN         NaN          NaN          NaN          NaN
# ...
